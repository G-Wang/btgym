# %% [markdown]
# ### Asynchronous BTgym environment setup.
# ****
# - This example shows base setup for asynchronious execution of multiply BTgym environment instances.
#
#
# - The main idea is to utilize separate BTgymDataFeedServer process to draw random episode data samples from one main dataset and pass it to every running environment.
#
#
# - This is quite a memory saver since every env. instance holds only small piece of data (single episode). Besides, sampling and dataset management is performed in it's own process.

# %%
import sys
sys.path.insert(0,'..')

import time
import multiprocessing

from btgym import BTgymEnv, BTgymDataset

# %%
class Worker(multiprocessing.Process):
    env = None
    
    def __init__(self, env_class, worker_id, num_episodes, env_config):
        super(Worker, self).__init__()
        self.env_class = env_class
        self.num_episodes = num_episodes
        self.env_config = env_config
        self.worker_id = worker_id
        
    def run(self):
        print('worker_{}: making environment...'.format(self.worker_id))
        self.env = self.env_class(**self.env_config)
        
        for episode in range(self.num_episodes):
            print('worker_{}: episode {} started.'.format(self.worker_id, episode))
            obs = self.env.reset()
            done = False
            while not done:
                # Just repeat `hold` action:
                obs, reward, done, info = self.env.step(0)
            # Get and report statistic:
            stat = self.env.get_stat() 
            print(
                'worker_{}: episode {} finished, {} steps made within {} seconds.'.
                  format(self.worker_id, stat['episode'], stat['length'], stat['runtime'])
            )   
        self.env.close()
        print('worker_{}: environmnt closed.'.format(self.worker_id))

# %%
# Provide data:
MyDataset = BTgymDataset(
    filename='../examples/data/DAT_ASCII_EURUSD_M1_2016.csv',
    start_weekdays=[0, 1, 2, 3, 4],
    episode_duration={'days': 1, 'hours': 23, 'minutes': 55},
    start_00=False,
    time_gap={'hours': 12},
)

# Setup:
num_workers = 8   # set it according to available CPU cores.
num_episodes = 2  # individual workplan.
base_port = 5000  # worker environment <--> BTgymServer communictaion, individual for every worker.
data_port = 4999  # BTgymServer <--> BTgymDataFeedServer communication, same for all workers.

workers = []

# Make data-master environment. In this example it will only serves as coordinator
# to start/stop data server, but can be exploited as full-time worker as well;
# just keep it runnung until others exit.
data_master = BTgymEnv(
    dataset=MyDataset,  # It is the only environment here for which dataset is required:
    port=5050,
    data_port=data_port,
    data_master=True,
    connect_timeout=10,  # set server connection timeout to 10 second (default is 60).
    verbose=0,
)

o = data_master.reset() # fake reset() to start data_server_process

# Make and launch workers in separate processes:
for i in range(num_workers):
    # Worker environment configuration:
    env_config=dict(
        port=base_port + i,
        data_port=data_port,
        data_master=False,  # This option forces environmnet to seek for datafeed provider server
                            # rather to use own dataset. Thus, no dataset is specified for this env.
        connect_timeout=10,
        verbose=0,
    )
    
    # Make:
    worker = Worker(
        env_class=BTgymEnv,
        worker_id=i,
        num_episodes=num_episodes,
        env_config=env_config,
    )
    
    # Launch:
    worker.daemon = False
    worker.start()
    workers.append(worker)
    # Artificial async, no need for this in real training:
    time.sleep(0.1)
    
# Wait everyone to finish:
for worker in workers:
    worker.join()
    print('...worker_{} has joined.'.format(worker.worker_id))
    
# shutdown data server :
data_master.close()

print('data_master: environment closed.')

# %% [markdown]
# ### Under the hood:
# *****
# ...for those who interested in what internal communications are going on:
#
# - just set **`verbose=2*`**:
#
#
# *-DEBUG level - do not use that in real life due to data overflood.

# %%
MyDataset = BTgymDataset(
    filename='../examples/data/DAT_ASCII_EURUSD_M1_2016.csv',
    start_weekdays=[0, 1, 2, 3, 4],
    episode_duration={'days': 1, 'hours': 23, 'minutes': 55},
    start_00=False,
    time_gap={'hours': 12},
)

env1 = BTgymEnv(
    dataset=MyDataset,
    port=5050,
    data_port=4999,
    data_master=True,
    connect_timeout=5,
    verbose=2,
)

env2 = BTgymEnv(
    port=5052,
    data_port=4999,
    data_master=False,
    connect_timeout=5,
    verbose=2,
)

_1 = env1.reset()
_2 = env2.reset()

env2.close()
env1.close()
# Out:
# [2017-12-19 16:35:42,291] Custom Dataset class used.
# [2017-12-19 16:35:42,292] Connecting data_server...
# [2017-12-19 16:35:42,489] DataServer PID: 48249
# [2017-12-19 16:35:43,315] Loaded 372678 records from <../examples/data/DAT_ASCII_EURUSD_M1_2016.csv>.
# [2017-12-19 16:35:43,403] Data summary:
#                 open           high            low          close    volume
# count  372678.000000  372678.000000  372678.000000  372678.000000  372678.0
# mean        1.107109       1.107198       1.107019       1.107108       0.0
# std         0.024843       0.024840       0.024847       0.024844       0.0
# min         1.035250       1.035470       1.035220       1.035220       0.0
# 25%         1.092140       1.092230       1.092040       1.092140       0.0
# 50%         1.113530       1.113610       1.113450       1.113530       0.0
# 75%         1.124710       1.124780       1.124630       1.124710       0.0
# max         1.161440       1.161600       1.160770       1.161450       0.0
# [2017-12-19 16:35:43,407] If_sample: data_ready: False, fresh_sample: False
# [2017-12-19 16:35:43,490] Pinging data_server at: tcp://127.0.0.1:4999 ...
# [2017-12-19 16:35:43,493] DataServer received <{'ctrl': 'ping!'}>
# [2017-12-19 16:35:43,494] DataServer sent: {'ctrl': 'waiting for control keys:  <_reset_data>, <_get_data>, <_get_info>, <_stop>.'}
# [2017-12-19 16:35:43,496] Data_server seems ready with response: <{'ctrl': 'waiting for control keys:  <_reset_data>, <_get_data>, <_get_info>, <_stop>.'}>
# [2017-12-19 16:35:43,496] If_sample: data_ready: False, fresh_sample: False
# [2017-12-19 16:35:43,497] DataServer received <{'ctrl': '_get_info'}>
# [2017-12-19 16:35:43,498] Sending info for #0.
# [2017-12-19 16:35:43,500] If_sample: data_ready: False, fresh_sample: False
# [2017-12-19 16:35:43,502] ...done.
# [2017-12-19 16:35:43,504] Base Cerebro class used. Base Strategy class used.
# [2017-12-19 16:35:43,513] Inferring `state_raw` high/low values form dataset: 1.035220 / 1.161600.
# [2017-12-19 16:35:43,514] Obs. shape: OrderedDict([('raw_state', Box(4, 4))])
# [2017-12-19 16:35:43,602] BTgymServer PID: 48254
# [2017-12-19 16:35:43,610] BtgymServer: pinging data_server at: tcp://127.0.0.1:4999 ...
# [2017-12-19 16:35:43,614] DataServer received <{'ctrl': 'ping!'}>
# [2017-12-19 16:35:43,616] DataServer sent: {'ctrl': 'waiting for control keys:  <_reset_data>, <_get_data>, <_get_info>, <_stop>.'}
# [2017-12-19 16:35:43,618] If_sample: data_ready: False, fresh_sample: False
# [2017-12-19 16:35:43,619] BTgymServer: Data_server seems ready with response: <{'ctrl': 'waiting for control keys:  <_reset_data>, <_get_data>, <_get_info>, <_stop>.'}>
# [2017-12-19 16:35:44,604] Server started, pinging tcp://127.0.0.1:5050 ...
# [2017-12-19 16:35:44,607] Server Control mode: received <{'ctrl': 'ping!'}>
# [2017-12-19 16:35:44,609] Server sent: {'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}
# [2017-12-19 16:35:44,610] Server seems ready with response: <{'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}>
# [2017-12-19 16:35:44,611] Environment is ready.
# [2017-12-19 16:35:44,616] Connecting data_server...
# [2017-12-19 16:35:44,617] Pinging data_server at: tcp://127.0.0.1:4999 ...
# [2017-12-19 16:35:44,618] DataServer received <{'ctrl': 'ping!'}>
# [2017-12-19 16:35:44,620] DataServer sent: {'ctrl': 'waiting for control keys:  <_reset_data>, <_get_data>, <_get_info>, <_stop>.'}
# [2017-12-19 16:35:44,623] Data_server seems ready with response: <{'ctrl': 'waiting for control keys:  <_reset_data>, <_get_data>, <_get_info>, <_stop>.'}>
# [2017-12-19 16:35:44,623] If_sample: data_ready: False, fresh_sample: False
# [2017-12-19 16:35:44,625] DataServer received <{'ctrl': '_get_info'}>
# [2017-12-19 16:35:44,627] Sending info for #0.
# [2017-12-19 16:35:44,629] If_sample: data_ready: False, fresh_sample: False
# [2017-12-19 16:35:44,631] ...done.
# [2017-12-19 16:35:44,633] Base Cerebro class used. Base Strategy class used.
# [2017-12-19 16:35:44,640] Inferring `state_raw` high/low values form dataset: 1.035220 / 1.161600.
# [2017-12-19 16:35:44,641] Obs. shape: OrderedDict([('raw_state', Box(4, 4))])
# [2017-12-19 16:35:44,682] BTgymServer PID: 48259
# [2017-12-19 16:35:44,687] BtgymServer: pinging data_server at: tcp://127.0.0.1:4999 ...
# [2017-12-19 16:35:44,689] DataServer received <{'ctrl': 'ping!'}>
# [2017-12-19 16:35:44,691] DataServer sent: {'ctrl': 'waiting for control keys:  <_reset_data>, <_get_data>, <_get_info>, <_stop>.'}
# [2017-12-19 16:35:44,692] If_sample: data_ready: False, fresh_sample: False
# [2017-12-19 16:35:44,692] BTgymServer: Data_server seems ready with response: <{'ctrl': 'waiting for control keys:  <_reset_data>, <_get_data>, <_get_info>, <_stop>.'}>
# [2017-12-19 16:35:45,679] Server started, pinging tcp://127.0.0.1:5052 ...
# [2017-12-19 16:35:45,682] Server Control mode: received <{'ctrl': 'ping!'}>
# [2017-12-19 16:35:45,684] Server sent: {'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}
# [2017-12-19 16:35:45,687] Server seems ready with response: <{'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}>
# [2017-12-19 16:35:45,688] Environment is ready.
# [2017-12-19 16:35:45,690] DataServer received <{'ctrl': '_get_info'}>
# [2017-12-19 16:35:45,693] Sending info for #0.
# [2017-12-19 16:35:45,695] If_sample: data_ready: False, fresh_sample: False
# [2017-12-19 16:35:45,697] Data_master `reset()` called prior to `reset_data()` with [possibly inconsistent] defaults.
# [2017-12-19 16:35:45,699] Server Control mode: received <{'ctrl': '_done'}>
# [2017-12-19 16:35:45,702] Server sent: {'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}
# [2017-12-19 16:35:45,704] FORCE CONTROL MODE attempt: 1.
# Response: {'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}
# [2017-12-19 16:35:45,705] DataServer received <{'ctrl': '_reset_data', 'kwargs': {}}>
# [2017-12-19 16:35:46,538] Loaded 372678 records from <../examples/data/DAT_ASCII_EURUSD_M1_2016.csv>.
# [2017-12-19 16:35:46,550] DataServer sent: {'ctrl': 'Dataset has been reset with kwargs: {}'}
# [2017-12-19 16:35:46,552] [_reset_data]: data_is_ready: True
# [2017-12-19 16:35:46,553] Dataset seems ready with response: <{'ctrl': 'Dataset has been reset with kwargs: {}'}>
# [2017-12-19 16:35:46,553] If_sample: data_ready: True, fresh_sample: False
# [2017-12-19 16:35:46,555] Server Control mode: received <{'ctrl': '_done'}>
# [2017-12-19 16:35:46,555] Maximum sample time duration set to: 1 day, 23:55:00.
# [2017-12-19 16:35:46,558] Server sent: {'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}
# [2017-12-19 16:35:46,559] Respective number of steps: 2875.
# [2017-12-19 16:35:46,560] FORCE CONTROL MODE attempt: 1.
# Response: {'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}
# [2017-12-19 16:35:46,561] Maximum allowed data time gap set to: 12:00:00.
# [2017-12-19 16:35:46,562] Server Control mode: received <{'ctrl': '_reset'}>
#
# [2017-12-19 16:35:46,563] Starting episode.
# [2017-12-19 16:35:46,565] Episode start: 2016-07-04 22:38:00, weekday: 0.
# [2017-12-19 16:35:46,585] Episode duration: 1 day, 23:57:00.
# [2017-12-19 16:35:46,587] Total episode time gap: 0:02:00.
# [2017-12-19 16:35:46,589] Sample accepted.
# [2017-12-19 16:35:46,591] Episode id: <_btgym_random_sample_2016-07-04 22:38:00>.
# [2017-12-19 16:35:46,614] Got fresh: episode #0 metadata:
# {'type': False, 'first_row': 188719, 'trial_num': False, 'sample_num': False}
# [2017-12-19 16:35:46,618] DataServer received <{'ctrl': '_get_data'}>
# [2017-12-19 16:35:46,630] Sending episode #0 data {'metadata': {'type': False, 'first_row': 188719, 'trial_num': False, 'sample_num': False}, 'datafeed': <backtrader.feeds.pandafeed.PandasDirectData object at 0x10c4c57f0>, 'episode_stat':               open         high          low        close  volume
# count  2875.000000  2875.000000  2875.000000  2875.000000  2875.0
# mean      1.109100     1.109208     1.108987     1.109098     0.0
# std       0.003398     0.003401     0.003397     0.003397     0.0
# min       1.103650     1.103840     1.102900     1.103630     0.0
# 25%       1.106400     1.106510     1.106240     1.106400     0.0
# 50%       1.108560     1.108660     1.108490     1.108560     0.0
# 75%       1.112505     1.112615     1.112365     1.112500     0.0
# max       1.118320     1.118510     1.117470     1.118340     0.0, 'dataset_stat':                 open           high            low          close    volume
# count  372678.000000  372678.000000  372678.000000  372678.000000  372678.0
# mean        1.107109       1.107198       1.107019       1.107108       0.0
# std         0.024843       0.024840       0.024847       0.024844       0.0
# min         1.035250       1.035470       1.035220       1.035220       0.0
# 25%         1.092140       1.092230       1.092040       1.092140       0.0
# 50%         1.113530       1.113610       1.113450       1.113530       0.0
# 75%         1.124710       1.124780       1.124630       1.124710       0.0
# max         1.161440       1.161600       1.160770       1.161450       0.0, 'local_step': 0}.
# [2017-12-19 16:35:46,636] If_sample: data_ready: True, fresh_sample: False
# [2017-12-19 16:35:46,638] Maximum sample time duration set to: 1 day, 23:55:00.
# [2017-12-19 16:35:46,640] Data_server responded with datafeed in about 0.07253503799438477 seconds.
# [2017-12-19 16:35:46,640] Respective number of steps: 2875.
# [2017-12-19 16:35:46,642] Maximum allowed data time gap set to: 12:00:00.
# [2017-12-19 16:35:46,649] Kwargs:
# {'metadata': {'type': False, 'first_row': 188719, 'trial_num': False, 'sample_num': False}}
#
#
# [2017-12-19 16:35:46,654] Episode start: 2016-07-04 09:42:00, weekday: 0.
# [2017-12-19 16:35:46,658] Episode duration: 1 day, 23:59:00.
# [2017-12-19 16:35:46,663] Total episode time gap: 0:04:00.
# [2017-12-19 16:35:46,665] Sample accepted.
# [2017-12-19 16:35:46,667] Inner time embedding: 4
# [2017-12-19 16:35:46,668] Episode id: <_btgym_random_sample_2016-07-04 09:42:00>.
# [2017-12-19 16:35:46,670] COMM recieved: {'action': 'hold'}
# [2017-12-19 16:35:46,674] Env response checker received:
# ({'raw_state': array([[ 1.11328,  1.11331,  1.11326,  1.1133 ],
#        [ 1.11332,  1.11332,  1.11328,  1.11331],
#        [ 1.11331,  1.11331,  1.11323,  1.11325],
#        [ 1.11324,  1.11324,  1.11309,  1.11312]])}, 0.0, False, [{'step': 1, 'time': datetime.datetime(2016, 7, 4, 22, 41), 'action': 'hold', 'broker_message': '-', 'broker_cash': 10.0, 'broker_value': 10.0, 'drawdown': 0.0, 'max_drawdown': 0.0}])
# as type: <class 'tuple'>
# [2017-12-19 16:35:46,676] Server Control mode: received <{'ctrl': '_done'}>
# [2017-12-19 16:35:46,679] Server sent: {'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}
# [2017-12-19 16:35:46,682] FORCE CONTROL MODE attempt: 1.
# Response: {'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}
# [2017-12-19 16:35:46,683] Server Control mode: received <{'ctrl': '_reset'}>
# [2017-12-19 16:35:46,689] Starting episode.
# [2017-12-19 16:35:46,693] Got fresh: episode #1 metadata:
# {'type': False, 'first_row': 187947, 'trial_num': False, 'sample_num': False}
# [2017-12-19 16:35:46,698] DataServer received <{'ctrl': '_get_data'}>
# [2017-12-19 16:35:46,709] Sending episode #1 data {'metadata': {'type': False, 'first_row': 187947, 'trial_num': False, 'sample_num': False}, 'datafeed': <backtrader.feeds.pandafeed.PandasDirectData object at 0x10c5e2a58>, 'episode_stat':              open         high          low        close  volume
# count  2875.00000  2875.000000  2875.000000  2875.000000  2875.0
# mean      1.11062     1.110714     1.110522     1.110618     0.0
# std       0.00410     0.004090     0.004112     0.004100     0.0
# min       1.10365     1.103840     1.103600     1.103630     0.0
# 25%       1.10661     1.106720     1.106470     1.106605     0.0
# 50%       1.11273     1.112820     1.112650     1.112720     0.0
# 75%       1.11451     1.114570     1.114410     1.114510     0.0
# max       1.11832     1.118510     1.117470     1.118340     0.0, 'dataset_stat':                 open           high            low          close    volume
# count  372678.000000  372678.000000  372678.000000  372678.000000  372678.0
# mean        1.107109       1.107198       1.107019       1.107108       0.0
# std         0.024843       0.024840       0.024847       0.024844       0.0
# min         1.035250       1.035470       1.035220       1.035220       0.0
# 25%         1.092140       1.092230       1.092040       1.092140       0.0
# 50%         1.113530       1.113610       1.113450       1.113530       0.0
# 75%         1.124710       1.124780       1.124630       1.124710       0.0
# max         1.161440       1.161600       1.160770       1.161450       0.0, 'local_step': 1}.
# [2017-12-19 16:35:46,714] If_sample: data_ready: True, fresh_sample: False
# [2017-12-19 16:35:46,716] Maximum sample time duration set to: 1 day, 23:55:00.
# [2017-12-19 16:35:46,719] Data_server responded with datafeed in about 0.025304079055786133 seconds.
# [2017-12-19 16:35:46,721] Respective number of steps: 2875.
# [2017-12-19 16:35:46,724] Maximum allowed data time gap set to: 12:00:00.
#
# [2017-12-19 16:35:46,728] Episode start: 2016-01-15 01:32:00, weekday: 4.
# [2017-12-19 16:35:46,730] Kwargs:
# {'metadata': {'type': False, 'first_row': 187947, 'trial_num': False, 'sample_num': False}}
#
# [2017-12-19 16:35:46,733] Episode duration: 4 days, 0:03:00.
# [2017-12-19 16:35:46,735] Total episode time gap: 2 days, 0:08:00.
# [2017-12-19 16:35:46,737] Duration too big, resampling...
#
# [2017-12-19 16:35:46,741] Episode start: 2016-10-06 19:37:00, weekday: 3.
# [2017-12-19 16:35:46,745] Episode duration: 4 days, 0:06:00.
# [2017-12-19 16:35:46,746] Inner time embedding: 4
# [2017-12-19 16:35:46,749] Total episode time gap: 2 days, 0:11:00.
# [2017-12-19 16:35:46,749] COMM recieved: {'action': 'hold'}
# [2017-12-19 16:35:46,752] Env response checker received:
# ({'raw_state': array([[ 1.114  ,  1.114  ,  1.11377,  1.11389],
#        [ 1.11386,  1.11393,  1.11381,  1.11393],
#        [ 1.11392,  1.11407,  1.1139 ,  1.11395],
#        [ 1.11395,  1.11413,  1.11389,  1.11404]])}, 0.0, False, [{'step': 1, 'time': datetime.datetime(2016, 7, 4, 9, 45), 'action': 'hold', 'broker_message': '-', 'broker_cash': 10.0, 'broker_value': 10.0, 'drawdown': 0.0, 'max_drawdown': 0.0}])
# as type: <class 'tuple'>
# [2017-12-19 16:35:46,751] Duration too big, resampling...
#
# [2017-12-19 16:35:46,755] COMM recieved: {'ctrl': '_done'}
# [2017-12-19 16:35:46,757] FORCE CONTROL MODE attempt: 1.
# Response: _DONE SIGNAL RECEIVED
# [2017-12-19 16:35:46,756] Episode start: 2016-11-07 21:08:00, weekday: 0.
# [2017-12-19 16:35:46,757] RunStop() invoked with -
# [2017-12-19 16:35:46,774] Episode duration: 1 day, 23:55:00.
# [2017-12-19 16:35:46,776] Total episode time gap: 0:00:00.
# [2017-12-19 16:35:46,778] Sample accepted.
# [2017-12-19 16:35:46,780] Episode id: <_btgym_random_sample_2016-11-07 21:08:00>.
# [2017-12-19 16:35:46,806] Got fresh: episode #2 metadata:
# {'type': False, 'first_row': 317859, 'trial_num': False, 'sample_num': False}
# [2017-12-19 16:35:47,975] Episode elapsed time: 0:00:01.282737.
# [2017-12-19 16:35:48,060] Server Control mode: received <{'ctrl': '_done'}>
# [2017-12-19 16:35:48,062] Server sent: {'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}
# [2017-12-19 16:35:48,063] FORCE CONTROL MODE attempt: 2.
# Response: {'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}
# [2017-12-19 16:35:48,064] Server Control mode: received <{'ctrl': '_stop'}>
# [2017-12-19 16:35:48,066] Server is exiting.
# [2017-12-19 16:35:48,068] Server is exiting. Exit code: None
# [2017-12-19 16:35:48,070] Environment closed.
# [2017-12-19 16:35:48,072] COMM recieved: {'ctrl': '_done'}
# [2017-12-19 16:35:48,074] FORCE CONTROL MODE attempt: 1.
# Response: _DONE SIGNAL RECEIVED
# [2017-12-19 16:35:48,074] RunStop() invoked with -
# [2017-12-19 16:35:48,857] Episode elapsed time: 0:00:02.292071.
# [2017-12-19 16:35:48,940] Server Control mode: received <{'ctrl': '_done'}>
# [2017-12-19 16:35:48,941] Server sent: {'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}
# [2017-12-19 16:35:48,943] FORCE CONTROL MODE attempt: 2.
# Response: {'ctrl': 'send control keys: <_reset>, <_getstat>, <_render>, <_stop>.'}
# [2017-12-19 16:35:48,944] Server Control mode: received <{'ctrl': '_stop'}>
# [2017-12-19 16:35:48,945] Server is exiting.
# [2017-12-19 16:35:48,947] Server is exiting. Exit code: None
# [2017-12-19 16:35:48,949] DataServer received <{'ctrl': '_stop'}>
# [2017-12-19 16:35:48,951] {'ctrl': 'DataServer is exiting.'}
# [2017-12-19 16:35:48,952] Environment closed.

# %%
dir(data_master)
